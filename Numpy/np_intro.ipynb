# %%
import numpy as np

# %%
python_list = [1,2,3,4,-5]

# %%
python_list
# Out:
# [1, 2, 3, 4, -5]

# %%
np_array=np.array(python_list)

# %%
len(np_array.shape)
# Out:
# 1

# %%
two_dlist=[[1,2],[3,4]]

# %%
np_scndarray=np.array(two_dlist)

# %%
len(np_scndarray.shape)
# Out:
# 2

# %%
newlist=list(range(5))
newlist
# Out:
# [0, 1, 2, 3, 4]

# %%
oholist=np.arange(5)
oholist               #directly create a numpy array
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.zeros((4,2,1))    #np.ones((2,2)) similar function
# Out:
# array([[[0.],
#         [0.]],
#
#        [[0.],
#         [0.]],
#
#        [[0.],
#         [0.]],
#
#        [[0.],
#         [0.]]])

# %%
np.random.randint(5,size=(2,5))  #randomizes the matrix
# Out:
# array([[2, 0, 2, 4, 3],
#        [3, 0, 0, 1, 0]])

# %%
a=[1,2,3,4]
arr=np.array(a,dtype=np.int32)  #extra parameter to explicitly convert to a certain datatype
arr.dtype
# Out:
# dtype('int32')

# %%
#numpy automatically normalises the datatype while converting a list to a nparray
arr_new=[5.2,4.2,5]
arr2 = np.array(arr2)
arr2.dtype
# Out:
# dtype('float64')

# %%
#to convert an array to a datatype
arr3 = arr2.astype(int)
arr2.dtype           #the original array type remains same, astype creates a copy of the array and changes its type
arr3.dtype
# Out:
# dtype('int64')
