# %%
import numpy as np

# %%
#for matrices a x b and c x d, b=c for multiplication

# %%
#it is used for getting the weighted sum. (Specific usecase, otherwise yk what is matrix multiplication)

# %%
#for example we have the marks matrix per subject
marks = np.random.randint(6,size=(3,4))
marks
# Out:
# array([[4, 2, 3, 1],
#        [3, 2, 3, 1],
#        [1, 1, 0, 1]])

# %%
#so the percentage of student 1 will be (4+2+3+1/40) *100, keeping the weightage of each subjet 25%
#but if we wanted to give 40% weightage to maths and 20% to each other subject, we will do something like this
# 40% of 4 + 20% of 2 + 20% of 3 + 20% of 1 = 1.6+ 0.4 + 0.6 + 0.2 = 2.8 - on avg, the person has scored 2.8 marks out of 10. each subject was of 10 marks na.

#this can be done by matrix multiplication of marks arr and an array [[0.4],
  #                                                                   [0.2],
  #                                                                   [0.2],
  #                                                                   [0.2]]
